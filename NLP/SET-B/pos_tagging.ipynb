# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# download required models
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /Users/deepak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/deepak/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
sentence = "Arun is working in Infosys in Bangalore today"

# %%
tokens = word_tokenize(sentence)
pos_tags = pos_tag(tokens)

# %%
print("Tokens:", tokens)
print("POS Tags:", pos_tags)
# Out:
# Tokens: ['Arun', 'is', 'working', 'in', 'Infosys', 'in', 'Bangalore', 'today']
# POS Tags: [('Arun', 'NNP'), ('is', 'VBZ'), ('working', 'VBG'), ('in', 'IN'), ('Infosys', 'NNP'), ('in', 'IN'), ('Bangalore', 'NNP'), ('today', 'NN')]
